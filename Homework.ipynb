# %% [markdown]
# <a href="https://colab.research.google.com/github/lukezhou10/bte320/blob/main/Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework

# %% [markdown]
# ## Assignment 1: Quality Control
#
# A quality control manager would like to find the average weight of a list of weights. Prior experience indicates that the first two measures are atypical, and the practice is to exclude these from the average calculation.
#
# Write a program that calculates the average of a list of numbers that given as inputs from the user, excluding the first two values.
#
# For your program, you must define and use the following functions:
# - `getValues(n)`: Prompt the user for `n` values, returns the list
# - `calcAverage(alist)`: Calculates the average from the list

# %%
def getValues(n):
    values = []
    for i in range(n):
        val = float(input(f"Enter value {i+1}: "))
        values.append(val)
    return values


def calcAverage(alist):
    # exclude first two values
    filtered = alist[2:]

    # avoid division by zero
    if len(filtered) == 0:
        return 0

    return sum(filtered) / len(filtered)


# Main program
n = int(input("How many values? "))

numbers = getValues(n)
average = calcAverage(numbers)

print("Average (excluding first two values):", average)
# Out:
# How many values? 10
# Enter value 1: 1
# Enter value 2: 2
# Enter value 3: 3
# Enter value 4: 4
# Enter value 5: 5
# Enter value 6: 2
# Enter value 7: 5
# Enter value 8: 4
# Enter value 9: 3
# Enter value 10: 2
# Average (excluding first two values): 3.5

# %% [markdown]
# ## Assignment 2: Parking Garage
#
# Write a program to compute the fee for parking in a garage for a number of hours.
#
# The program should:
# - Prompt the user for how many hours parked
# - Calculate the fee based on the following rules:
#   - $2.50/hour
#
#   - minimum fee is $6.00
#
#   - maximum fee is $20.00
# - Print the result
#
# For your program, define and use the following two functions:
# ```python
# # use input() to prompt for the # of hours parked, return this value
# def getParkingHours()
#
# # takes as input hours (a number), returns the parking fee
# def calcParkingFee()
# ```

# %%
# use input() to prompt for the # of hours parked, return this value
def getParkingHours():
    hours = float(input("Enter number of hours parked: "))
    return hours


# takes as input hours (a number), returns the parking fee
def calcParkingFee(hours):
    fee = hours * 2.50

    # apply minimum fee
    if fee < 6.00:
        fee = 6.00

    # apply maximum fee
    if fee > 20.00:
        fee = 20.00

    return fee


# Main program
hours = getParkingHours()
fee = calcParkingFee(hours)

print("Parking fee: $", round(fee, 2))
# Out:
# Enter number of hours parked: 4
# Parking fee: $ 10.0

# %% [markdown]
# ## Assignment 3: Tuition
#
# A college charges tuition according to the following:
# - 12 or more credits: $20,000/semester
#
# - 1-11 credits: $1,200 + $1,700 per credit
#
# Write a program that prompts the user for a number of credits and determines and displays the tuition for the semester. As part of your program, define and use the following function:
# ```python
# def calcTuition(credits)
# ```
# The function returns the tuition for a given number of credits

# %%
def calcTuition(credits):
    if credits >= 12:
        return 20000
    else:
        return credits * 1200


# Main program
credits = int(input("Enter number of credits: "))
tuition = calcTuition(credits)

print("Tuition for the semester: $", tuition)
# Out:
# Enter number of credits: 3
# Tuition for the semester: $ 3600
