# %% [markdown]
# <a href="https://colab.research.google.com/github/lukezhou10/bte320/blob/main/In_class_assignments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sales = 12000
cogs = sales * .40
gross_profit = sales - cogs
print("gross profit", "$", profit)
print("cost of goods sold","$",cogs)
print("sales","$", sales)
# Out:
# gross profit $ 7200.0
# cost of goods sold $ 4800.0
# sales $ 12000

# %%
sales = float(input("enter sales value ($):"))

cogs = 0.40 * sales
gross_profit = sales - cogs

print(f"sales: {sales}$")
print(f"cost of goods sold: {cogs}$")
print(f"gross profit: {gross_profit}$")
# Out:
# enter sales value ($):12000
# sales: 12000.0$
# cost of goods sold: 4800.0$
# gross profit: 7200.0$

# %%
sales = float(input("enter sales value ($):"))
Tax_rate= float(input("enter tax rate (%):"))
cogs = 0.40 * sales
gross_profit = sales - cogs
tax = gross_profit * (Tax_rate/100)
net_income = gross_profit - tax
print("gross_profit : gross profit")
print("tax: tax")
print("net_income: net income")
# Out:
# enter sales value ($):3000
# enter tax rate (%):40
# gross_profit : gross profit
# tax: tax
# net_income: net income

# %%
x = int(input("enter number here: "))
y = int(input("enter number here: "))
z = (input("enter operator: "))

if z =="+":
  answer = x + y
elif z == "-":
  answer = x - y
elif z == "*":
  answer = x * y
elif z == "/":
  answer = x / y
else:
  print("invalid operator")
print(answer)
# Out:
# enter number here: 3
# enter number here: 4
# enter operator: -
# -1
